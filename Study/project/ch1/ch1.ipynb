# %% [markdown]
# # Chapter 1. 컴퓨터는 데이터에서 배운다.

# %% [markdown]
# ### 1.2 머신 러닝의 세 가지 종류
# 1) 지도 학습
# - 레이블된 데이터
# - 직접 피드백
# - 출력 및 미래 예측
#
# ![Supervised-learning.png](attachment:Supervised-learning.png)

# %% [markdown]
# 2) 비지도 학습
# - 레이블 및 타깃 없음
# - 피드백 없음
# - 데이터에서 숨겨진 구조 찾기
#
# ![Unsupervised-learning.png](attachment:Unsupervised-learning.png)

# %% [markdown]
# 3) 준 지도 학습 (참고 링크 : https://sanghyu.tistory.com/177 )
# - 데이터가 전문적인 데이터이며 레이블이 적은 경우 사용
#
# ![semi_supervised_learning.png](attachment:semi_supervised_learning.png)

# %% [markdown]
# #### 3.5) 지도학습과 비지도 학습 구분
#
# ![Task-guidance.png](attachment:Task-guidance.png)

# %% [markdown]
# 4) 강화 학습
# - 결정 과정
# - 보상 시스템
# - 연속된 행동에서 학습
#
# ![reinforcement_learning.png](attachment:reinforcement_learning.png)

# %% [markdown]
# #### 1.2.1 지도학습
# - 분류
# - 회귀

# %% [markdown]
# #### 1.2.2 강화 학습
# (참고 링크 https://medium.com/@vishnuvijayanpv/what-is-reinforcement-learning-e5dc827c8564 )

# %% [markdown]
# #### 1.2.3 비지도 학습
# - 클러스터
# - 차원 축소

# %% [markdown]
# ### 1.4 머신 러닝 시스템 구축 로드맵

# %% [markdown]
# <img src='https://miro.medium.com/max/700/0*Ed2uSoiCUsJJ_-6R' width='4500px' height='500px' title='design_flow'></img><br/>
